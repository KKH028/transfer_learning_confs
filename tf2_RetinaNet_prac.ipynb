# %%
from google.colab import drive
drive.mount('/content/google_drive')

# %%
# !mkdir "/content/google_drive/MyDrive/RetinaNet_prac/workspace"

# %%
# !mkdir "/content/google_drive/MyDrive/RetinaNet_prac/workspace/scripts"

# %%
# !mkdir "/content/google_drive/MyDrive/RetinaNet_prac/workspace/scripts/preprocessing"

# %%
# !mkdir "/content/google_drive/MyDrive/RetinaNet_prac/workspace/exported_models"

# %%
# !mkdir "/content/google_drive/MyDrive/RetinaNet_prac/workspace/images"

# %%
# !mkdir "/content/google_drive/MyDrive/RetinaNet_prac/workspace/annotations"

# %%
# !mkdir "/content/google_drive/MyDrive/RetinaNet_prac/workspace/models"

# %%
# !mkdir "/content/google_drive/MyDrive/RetinaNet_prac/workspace/pre_trained_models"

# %%
train_dir = "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/images/train"
test_dir = "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/images/test"

# %%
# This Colab requires TF 2.5.
# !pip install -U "tensorflow>=2.5"

# %%
# !pip install pandas

# %%
import os
import pathlib
import time

import matplotlib
import matplotlib.pyplot as plt

import io
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from six.moves.urllib.request import urlopen

import tensorflow as tf
# import tensorflow_hub as hub

tf.get_logger().setLevel('ERROR')

# %%
import re
from shutil import copyfile
import argparse
import math
import random

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/
# Out:
# /content

# %%
# Clone the tensorflow models repository
# !git clone --depth 1 https://github.com/tensorflow/models

# %% [markdown]
# 리눅스 계열
# * 데이반 : 소프트웨어 설치 방식 : apt[S/W 설치 프로그램]
#
# * 레드햇 : 소프트웨어 설치 방식 : yum[S/W 설치 프로그램]

# %%
# !sudo apt install -y protobuf-compiler

# %%
# %cd /content/models/research

# %%
# !pwd

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !git clone https://github.com/cocodataset/cocoapi.git

# %%
# %cd /content/models/research/cocoapi/PythonAPI

# %%
# !make

# %%
# !ls -al

# %%
# !cp -r pycocotools /content/models/research

# %%
# %cd /content

# %%
# %cd /content/models/research

# %%
# !ls -al

# %%
# !pwd

# %%
# !cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install .

# %%
# !python /content/models/research/object_detection/builders/model_builder_tf2_test.py

# %%
# %%bash
# sudo apt install -y protobuf-compiler
# cd models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cp object_detection/packages/tf2/setup.py .
# python -m pip install .

# %%
 # !ls -al "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/images/train/models"

# %%
# !rm -r "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/images/train/models"

# %%
# !cp "/content/models/research/object_detection/data/pascal_label_map.pbtxt" \
"/content/google_drive/MyDrive/RetinaNet_prac/workspace/annotations"

# %%
# !mv "/content/google_drive/MyDrive/RetinaNet_prac/workspace/annotations/pascal_label_map.pbtxt" \
"/content/google_drive/MyDrive/RetinaNet_prac/workspace/annotations/label_map.pbtxt"

# %%
# %cd "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/scripts/preprocessing"

# %%
# !pwd

# %%
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import ops as utils_ops

# %%
# %cd /content/

# %%
# !pwd

# %%
# !cp "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/annotations/train.record" \
"/content/google_drive/MyDrive/RetinaNet_prac/workspace/annotations"

# %%
# !cp "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/annotations/test.record" \
"/content/google_drive/MyDrive/RetinaNet_prac/workspace/annotations"

# %%
# !pwd

# %%
# %cd /content

# %%
# !mkdir "/content/google_drive/MyDrive/RetinaNet_prac/workspace/models/RetinaNet"

# %%
# !cp "/content/google_drive/MyDrive/tensorflow_OD_API_A/ssd_resnet50_v1_fpn/pipeline.config" \
"/content/google_drive/MyDrive/RetinaNet_prac/workspace/pre_trained_models"

# %%
# !python "/content/models/research/object_detection/model_main_tf2.py" \
--model_dir="/content/google_drive/MyDrive/RetinaNet_prac/workspace/models/RetinaNet" \
--pipeline_config_path="/content/google_drive/MyDrive/RetinaNet_prac/workspace/pre_trained_models/pipeline.config"

# %%
# !python /content/models/research/object_detection/model_main_tf2.py \
--model_dir="/content/google_drive/MyDrive/RetinaNet_prac/workspace/models/RetinaNet" \
--pipeline_config_path="/content/google_drive/MyDrive/RetinaNet_prac/workspace/pre_trained_models/pipeline.config" \
--checkpoint_dir="/content/google_drive/MyDrive/RetinaNet_prac/workspace/models/RetinaNet"

# %% [markdown]
# -----------------

# %%
# !mkdir "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v1"

# %%
# !cp "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/pre-trained-models/faster_rcnn_resnet50_v1_640x640_coco17_tpu-8/pipeline.config" \
"/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/pipeline.config"

# %%
# !cp "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/pre-trained-models/faster_rcnn_resnet50_v1_640x640_coco17_tpu-8/pipeline.config" \
"/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v1"

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir="/content/google_drive/MyDrive/RetinaNet_prac/workspace/models/RetinaNet"

# %%
# %tensorboard --logdir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v1"

# %%
# !python /content/models/research/object_detection/model_main_tf2.py \
--model_dir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v1" \
--pipeline_config_path="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v1/pipeline.config"

# %%
# !python /content/models/research/object_detection/model_main_tf2.py \
--model_dir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v1" \
--pipeline_config_path="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v1/pipeline.config" \
--checkpoint_dir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v1"

# %%
# first training mAP
#
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.491
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.326
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.355
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.158
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.402
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.647
# INFO:tensorflow:Eval metrics at step 5000
# I1115 00:54:49.425843 139633762793344 model_lib_v2.py:1015] Eval metrics at step 5000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.299957
# I1115 00:54:49.497573 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.299957 <<<<<<
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.490543
# I1115 00:54:49.499429 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.490543
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.326205
# I1115 00:54:49.500891 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.326205
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.038647
# I1115 00:54:49.502194 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.038647
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.148873
# I1115 00:54:49.503478 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.148873
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.382777
# I1115 00:54:49.504756 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.382777
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.355029
# I1115 00:54:49.506001 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.355029
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.523377
# I1115 00:54:49.507263 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.523377
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.549352
# I1115 00:54:49.508504 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.549352
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.157935
# I1115 00:54:49.509779 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.157935
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.402475
# I1115 00:54:49.511038 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.402475
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.646691
# I1115 00:54:49.512457 139633762793344 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.646691
# INFO:tensorflow:	+ Loss/RPNLoss/localization_loss: 0.207552
# I1115 00:54:49.513460 139633762793344 model_lib_v2.py:1018] 	+ Loss/RPNLoss/localization_loss: 0.207552
# INFO:tensorflow:	+ Loss/RPNLoss/objectness_loss: 0.162977
# I1115 00:54:49.514467 139633762793344 model_lib_v2.py:1018] 	+ Loss/RPNLoss/objectness_loss: 0.162977
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/localization_loss: 0.156556
# I1115 00:54:49.515463 139633762793344 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/localization_loss: 0.156556
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/classification_loss: 0.222181
# I1115 00:54:49.516452 139633762793344 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/classification_loss: 0.222181
# INFO:tensorflow:	+ Loss/regularization_loss: 0.000000
# I1115 00:54:49.517447 139633762793344 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.000000
# INFO:tensorflow:	+ Loss/total_loss: 0.749267
# I1115 00:54:49.518442 139633762793344 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.749267 <<<<<<
# INFO:tensorflow:Exiting evaluation at step 5000
# I1115 00:54:49.826897 139633762793344 model_lib_v2.py:1168] Exiting evaluation at step 5000

# %%
# !ps

# %%
# !kill
# Out:
# kill: usage: kill [-s sigspec | -n signum | -sigspec] pid | jobspec ... or kill -l [sigspec]

# %%
# %tensorboard --logdir="/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/models/myft_faster_rcnn_resnet50_v1"

# %%
# !mkdir "/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/exported-models/saved_faster_rcnn_resnet50_v1"

# %%
# !python /content/models/research/object_detection/exporter_main_v2.py \
--input_type image_tensor \
--pipeline_config_path "/content/google_drive/MyDrive/RetinaNet_prac/workspace/pre_trained_models/pipeline.config" \
--trained_checkpoint_dir "/content/google_drive/MyDrive/tensorflow_OD_API_A/ssd_resnet50_v1_fpn/workspace/training_demo/models/myft_ssd_resnet50_v1_fpn" \
--output_directory "/content/google_drive/MyDrive/RetinaNet_prac/workspace/exported_models"

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings
import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
# %matplotlib inline

# %%
def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.

    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.

    Args:
      path: the file path to the image

    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))

# %%
PATH_TO_MODEL_DIR = "/content/google_drive/MyDrive/RetinaNet_prac/workspace/exported_models"
PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"

# %%
print('Loading model...', end='')
start_time = time.time()

# Load saved model and build the detection function
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))
# Out:
# Loading model...Done! Took 12.34477162361145 seconds

# %%
category_index = label_map_util.create_category_index_from_labelmap("/content/google_drive/MyDrive/RetinaNet_prac/workspace/annotations/label_map.pbtxt",use_display_name=True)

# %%
# path = 
# file_list_jpg = [file for file in os.listdir(path) if file.endswith(".jpg")]

# %%
imageDir2 = "/content/google_drive/MyDrive/tensorflow_OD_API_A/ssd_resnet50_v1_fpn/workspace/training_demo/images/test"
IMAGE_PATHS = [imageDir2 + "/" + f for f in os.listdir(imageDir2) if f[-4:] in ['.jpg','.jpeg','.png']]
IMAGE_PATHS = IMAGE_PATHS[0:5]

# %%
IMAGE_PATHS = ["/content/google_drive/MyDrive/Tensorflow_OD_API/faster_rcnn_resnet50_v1/workspace/training_demo/images/test/2007_000332.jpg"]

# %%
for image_path in IMAGE_PATHS:

    print('Running inference for {}... '.format(image_path), end='')

    image_np = load_image_into_numpy_array(image_path)

    # Things to try:
    # Flip horizontally
    # image_np = np.fliplr(image_np).copy()

    # Convert image to grayscale
    # image_np = np.tile(
    #     np.mean(image_np, 2, keepdims=True), (1, 1, 3)).astype(np.uint8)

    # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
    input_tensor = tf.convert_to_tensor(image_np)
    # The model expects a batch of images, so add an axis with `tf.newaxis`.
    input_tensor = input_tensor[tf.newaxis, ...]

    # input_tensor = np.expand_dims(image_np, 0)
    detections = detect_fn(input_tensor)

    # All outputs are batches tensors.
    # Convert to numpy arrays, and take index [0] to remove the batch dimension.
    # We're only interested in the first num_detections.
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                   for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
          image_np_with_detections,
          detections['detection_boxes'],
          detections['detection_classes'],
          detections['detection_scores'],
          category_index,
          use_normalized_coordinates=True,
          max_boxes_to_draw=200,
          min_score_thresh=.30,
          agnostic_mode=False)

    plt.figure()
    plt.imshow(image_np_with_detections)
    print('Done')
plt.show()
# Out:
# Running inference for /content/google_drive/MyDrive/tensorflow_OD_API_A/ssd_resnet50_v1_fpn/workspace/training_demo/images/test/2008_004265.jpg... Done
# Running inference for /content/google_drive/MyDrive/tensorflow_OD_API_A/ssd_resnet50_v1_fpn/workspace/training_demo/images/test/2011_006858.jpg... Done
# Running inference for /content/google_drive/MyDrive/tensorflow_OD_API_A/ssd_resnet50_v1_fpn/workspace/training_demo/images/test/2007_003876.jpg... Done
# Running inference for /content/google_drive/MyDrive/tensorflow_OD_API_A/ssd_resnet50_v1_fpn/workspace/training_demo/images/test/2008_007519.jpg... Done
# Running inference for /content/google_drive/MyDrive/tensorflow_OD_API_A/ssd_resnet50_v1_fpn/workspace/training_demo/images/test/2012_000692.jpg... Done
